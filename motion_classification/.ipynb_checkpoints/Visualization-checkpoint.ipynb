# %%
import os
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import GaussianNB

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
clean_examples = pd.read_csv('MicrosoftGestureDataset-RC/data/P1_1_10_p06.csv',sep=' ',header=None).drop(xrange(0,20),axis=0).drop(0,axis=1).drop((xrange(4,80,4)),axis=1).drop(80)

# %%
clean_examples[[1,2,3]].loc[20]
example=clean_examples.loc[20]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x_vals = example[[1]]
y_vals = example[[2]]
z_vals = example[[3]]
x2_vals = example[[5]]
y2_vals = example[[6]]
z2_vals = example[[7]]
x3_vals = example[[9]]
y3_vals = example[[10]]
z3_vals = example[[11]]
x4_vals = example[[13]]
y4_vals = example[[14]]
z4_vals = example[[15]]
x5_vals = example[[17]]
y5_vals = example[[18]]
z5_vals = example[[19]]
x6_vals = example[[21]]
y6_vals = example[[22]]
z6_vals = example[[23]]

x7_vals = example[[25]]
y7_vals = example[[26]]
z7_vals = example[[27]]

x8_vals = example[[29]]
y8_vals = example[[30]]
z8_vals = example[[31]]

x9_vals = example[[33]]
y9_vals = example[[34]]
z9_vals = example[[35]]

x10_vals = example[[37]]
y10_vals = example[[38]]
z10_vals = example[[39]]

x11_vals = example[[41]]
y11_vals = example[[42]]
z11_vals = example[[43]]

x12_vals = example[[45]]
y12_vals = example[[46]]
z12_vals = example[[47]]

ax.scatter(x_vals,y_vals,z_vals,c='red')
ax.scatter(x2_vals,y2_vals,z2_vals,c='blue')
ax.scatter(x3_vals,y3_vals,z3_vals,c='green')
ax.scatter(x4_vals,y4_vals,z4_vals,c='pink')
ax.scatter(x5_vals,y5_vals,z5_vals,c='yellow')
ax.scatter(x6_vals,y6_vals,z6_vals,c='orange')
ax.scatter(x7_vals,y7_vals,z7_vals,c='red')
ax.scatter(x8_vals,y8_vals,z8_vals,c='blue')
ax.scatter(x9_vals,y9_vals,z9_vals,c='green')
ax.scatter(x10_vals,y10_vals,z10_vals,c='pink')
ax.scatter(x11_vals,y11_vals,z11_vals,c='yellow')
ax.scatter(x12_vals,y12_vals,z12_vals,c='orange')

# %%
fig = plt.figure()
ax = fig.add_subplot(111,)

x_vals = example[[1]]
y_vals = example[[2]]
z_vals = example[[3]]
x2_vals = example[[5]]
y2_vals = example[[6]]
z2_vals = example[[7]]
x3_vals = example[[9]]
y3_vals = example[[10]]
z3_vals = example[[11]]
x4_vals = example[[13]]
y4_vals = example[[14]]
z4_vals = example[[15]]
x5_vals = example[[17]]
y5_vals = example[[18]]
z5_vals = example[[19]]
x6_vals = example[[21]]
y6_vals = example[[22]]
z6_vals = example[[23]]

x7_vals = example[[25]]
y7_vals = example[[26]]
z7_vals = example[[27]]

x8_vals = example[[29]]
y8_vals = example[[30]]
z8_vals = example[[31]]

x9_vals = example[[33]]
y9_vals = example[[34]]
z9_vals = example[[35]]

x10_vals = example[[37]]
y10_vals = example[[38]]
z10_vals = example[[39]]

x11_vals = example[[41]]
y11_vals = example[[42]]
z11_vals = example[[43]]

x12_vals = example[[45]]
y12_vals = example[[46]]
z12_vals = example[[47]]

ax.scatter(x_vals,y_vals,z_vals,c='red')
ax.scatter(x2_vals,y2_vals,z2_vals,c='blue')
ax.scatter(x3_vals,y3_vals,z3_vals,c='green')
ax.scatter(x4_vals,y4_vals,z4_vals,c='pink')
ax.scatter(x5_vals,y5_vals,z5_vals,c='yellow')
ax.scatter(x6_vals,y6_vals,z6_vals,c='orange')
ax.scatter(x7_vals,y7_vals,z7_vals,c='red')
# ax.scatter(x8_vals,y8_vals,z8_vals,c='blue')
# ax.scatter(x9_vals,y9_vals,z9_vals,c='green')
# ax.scatter(x10_vals,y10_vals,z10_vals,c='pink')
# ax.scatter(x11_vals,y11_vals,z11_vals,c='yellow')
# ax.scatter(x12_vals,y12_vals,z12_vals,c='orange')
