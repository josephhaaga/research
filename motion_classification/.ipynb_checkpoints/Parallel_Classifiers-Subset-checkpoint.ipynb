# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from mpl_toolkits.mplot3d import Axes3D
from sklearn import naive_bayes as nb
from sklearn.cross_validation import train_test_split

# %%
raw = pd.read_csv('MicrosoftGestureDataset-RC/data/P1_1_12A_p21.csv',sep=' ',header=None)
raw=raw.drop(xrange(0,20),axis=0).drop(0,axis=1).drop((xrange(4,80,4)),axis=1).drop(80,axis=1)

# %%
column_names=['hip_center_x','hip_center_y','hip_center_z',
              'spine_x','spine_y','spine_z','shoulder_center_x',
              'shoulder_center_y','shoulder_center_z','head_x',
              'head_y','head_z','shoulder_left_x','shoulder_left_y',
             'shoulder_left_z','elbow_left_x','elbow_left_y','elbow_left_z',
             'wrist_left_x','wrist_left_y','wrist_left_z','hand_left_x',
              'hand_left_y','wrist_left_z','shoulder_right_x','shoulder_right_y',
             'shoulder_right_z','elbow_right_x','elbow_right_y','elbow_right_z',
             'wrist_right_x','wrist_right_y','wrist_right_z','hand_right_x',
             'hand_right_y','hand_right_z','hip_left_x','hip_left_y','hip_left_z',
             'knee_left_x','knee_left_y','knee_left_z','ankle_left_x','ankle_left_y',
             'ankle_left_z','foot_left_x','foot_left_y','foot_left_z','hip_right_x',
             'hip_right_y','hip_right_z','knee_right_x','knee_right_y','knee_right_z',
             'ankle_right_x','ankle_right_y','ankle_right_z','foot_right_x','foot_right_y',
             'foot_right_z']

raw.columns=column_names
len(column_names)
# Out:
# 60

# %%
len(raw.columns)
# Out:
# 60

# %%
# create DataFrame for each axis of each joint
# A BAD IDEA
# for i in column_names:
#     print i
#     exec('{} = pd.DataFrame([1,2,3,4])'.format(i))
# A BETTER IDEA
joints = {k: pd.DataFrame([]) for k in raw.columns }

# %%
gestures = pd.DataFrame()
labels = pd.Series()
labels_array=[]
sizes = [1];
i=0

for root, dirs, files in os.walk("MicrosoftGestureDataset-RC/data"):
    for file in files:
        while i<11:
            if file.endswith(".csv"):
    #             temp = pd.read_csv(os.path.join(root,file),sep=' ',header=None)[:539]
                temp = pd.read_csv(os.path.join(root,file),sep=' ',header=None).drop(xrange(0,20),axis=0).drop(0,axis=1).drop((xrange(4,80,4)),axis=1).drop(80,axis=1)
                temp
                temp.columns=column_names
                for joint_name in temp.columns:
                    joints[joint_name] = joints[joint_name].append(temp[joint_name])
                labels_array.append(file[file.find('_',3)+1:file.rfind('_')].replace('A',''))
                sizes.append(len(temp))
                i=i+1;
print str(i)+" gesture files loaded"
# Out:
# 11 gesture files loaded

# %%
# os.listdir(os.getcwd())
# pd.read_pickle(os.getcwd()+'/elbow_right_y.pkl')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-dc3fbfdf93fb> in <module>()
#       1 # os.listdir(os.getcwd())
#       2 os.listdir(os.getcwd())
# ----> 3 pd.read_pickle(os.getcwd()+'/elbow_right_y.pkl')
#
# /Users/josephhaaga/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      58
#      59     try:
# ---> 60         return try_read(path)
#      61     except:
#      62         if PY3:
#
# /Users/josephhaaga/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      55             except:
#      56                 with open(path, 'rb') as fh:
# ---> 57                     return pc.load(fh, encoding=encoding, compat=True)
#      58
#      59     try:
#
# /Users/josephhaaga/anaconda/lib/python2.7/site-packages/pandas/compat/pickle_compat.pyc in load(fh, encoding, compat, is_verbose)
#     114         up.is_verbose = is_verbose
#     115
# --> 116         return up.load()
#     117     except:
#     118         raise
#
# /Users/josephhaaga/anaconda/lib/python2.7/pickle.pyc in load(self)
#     856             while 1:
#     857                 key = read(1)
# --> 858                 dispatch[key](self)
#     859         except _Stop, stopinst:
#     860             return stopinst.value
#
# /Users/josephhaaga/anaconda/lib/python2.7/pickle.pyc in load_global(self)
#    1088         module = self.readline()[:-1]
#    1089         name = self.readline()[:-1]
# -> 1090         klass = self.find_class(module, name)
#    1091         self.append(klass)
#    1092     dispatch[GLOBAL] = load_global
#
# /Users/josephhaaga/anaconda/lib/python2.7/pickle.pyc in find_class(self, module, name)
#    1122     def find_class(self, module, name):
#    1123         # Subclasses may override this
# -> 1124         __import__(module)
#    1125         mod = sys.modules[module]
#    1126         klass = getattr(mod, name)
#
# ImportError: No module named indexes.base

# %%
classifiers = {k: nb.GaussianNB() for k in raw.columns }

# %%
# training/test set split
training_sets = {}
test_sets = {}
for c in classifiers:
    train, test = train_test_split(joints[c], test_size = 0.2);
#     training_sets[c]=train.dropna(axis=1,how='any');
#     test_sets[c]=test.dropna(axis=1,how='any');
    training_sets[c]=train.dropna(axis=1,how='all');
    test_sets[c]=test.dropna(axis=1,how='all');

# %%
# training_sets[c].dropna(axis=1,how='any')
# pd.isnull(raw).any(1).nonzero
np.where(raw[:].isnull())
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
subset = training_sets['ankle_left_x'][:20]

# %%
subset
# Out:
#     ankle_left_x  ankle_left_x  ankle_left_x  ankle_left_x  ankle_left_x  \
# 20     -0.088440     -0.088440     -0.088440     -0.088440     -0.088440
# 21     -0.088358     -0.088358     -0.088358     -0.088358     -0.088358
# 22     -0.088128     -0.088128     -0.088128     -0.088128     -0.088128
# 23     -0.087376     -0.087376     -0.087376     -0.087376     -0.087376
# 24     -0.087528     -0.087528     -0.087528     -0.087528     -0.087528
# 25     -0.087150     -0.087150     -0.087150     -0.087150     -0.087150
# 26     -0.087066     -0.087066     -0.087066     -0.087066     -0.087066
# 27     -0.087275     -0.087275     -0.087275     -0.087275     -0.087275
# 28     -0.087351     -0.087351     -0.087351     -0.087351     -0.087351
# 29     -0.087479     -0.087479     -0.087479     -0.087479     -0.087479
# 30     -0.087591     -0.087591     -0.087591     -0.087591     -0.087591
# 34     -0.087651     -0.087651     -0.087651     -0.087651     -0.087651
# 35     -0.087746     -0.087746     -0.087746     -0.087746     -0.087746
# 36     -0.087829     -0.087829     -0.087829     -0.087829     -0.087829
# 37     -0.087739     -0.087739     -0.087739     -0.087739     -0.087739
# 38     -0.087621     -0.087621     -0.087621     -0.087621     -0.087621
# 39     -0.087586     -0.087586     -0.087586     -0.087586     -0.087586
#
#     ankle_left_x  ankle_left_x  ankle_left_x
# 20     -0.088440     -0.088440     -0.088440
# 21     -0.088358     -0.088358     -0.088358
# 22     -0.088128     -0.088128     -0.088128
# 23     -0.087376     -0.087376     -0.087376
# 24     -0.087528     -0.087528     -0.087528
# 25     -0.087150     -0.087150     -0.087150
# 26     -0.087066     -0.087066     -0.087066
# 27     -0.087275     -0.087275     -0.087275
# 28     -0.087351     -0.087351     -0.087351
# 29     -0.087479     -0.087479     -0.087479
# 30     -0.087591     -0.087591     -0.087591
# 31     -0.087244     -0.087244     -0.087244
# 32     -0.087311     -0.087311     -0.087311
# 33     -0.087490     -0.087490     -0.087490
# 34     -0.087651     -0.087651     -0.087651
# 35     -0.087746     -0.087746     -0.087746
# 36     -0.087829     -0.087829     -0.087829
# 37     -0.087739     -0.087739     -0.087739
# 38     -0.087621     -0.087621     -0.087621
# 39     -0.087586     -0.087586     -0.087586

# %%
i = 0
for c in classifiers:
    try:
        classifiers[c] = classifiers[c].fit(training_sets[c],labels_array[:len(training_sets[c])])
        print 'classifier #'+str(i)+' trained'
    except ValueError as e:
        print(e)
    i=i+1
# Out:
# classifier #0 trained
# classifier #1 trained
# classifier #2 trained
# classifier #3 trained
# classifier #4 trained
# Found arrays with inconsistent numbers of samples: [   11 61916]
# classifier #6 trained
# classifier #7 trained
# classifier #8 trained
# classifier #9 trained
# classifier #10 trained
# classifier #11 trained
# classifier #12 trained
# classifier #13 trained
# classifier #14 trained
# classifier #15 trained
# classifier #16 trained
# classifier #17 trained
# classifier #18 trained
# classifier #19 trained
# classifier #20 trained
# classifier #21 trained
# classifier #22 trained
# classifier #23 trained
# classifier #24 trained
# classifier #25 trained
# classifier #26 trained
# classifier #27 trained
# classifier #28 trained
# classifier #29 trained
# classifier #30 trained
# classifier #31 trained
# classifier #32 trained
# classifier #33 trained
# classifier #34 trained
# classifier #35 trained
# classifier #36 trained
# classifier #37 trained
# classifier #38 trained
# classifier #39 trained
# classifier #40 trained
# classifier #41 trained
# classifier #42 trained
# classifier #43 trained
# classifier #44 trained
# classifier #45 trained
# classifier #46 trained
# classifier #47 trained
# classifier #48 trained
# classifier #49 trained
# classifier #50 trained
# classifier #51 trained
# classifier #52 trained
# classifier #53 trained
# classifier #54 trained
# classifier #55 trained
# classifier #56 trained
# classifier #57 trained
# classifier #58 trained
