# %%
import pandas as pd
import numpy as np
from sklearn import naive_bayes as nb
import os
import matplotlib

# %%
numbers=[]
for i in xrange(1,14):
    numbers.append([])

# %%
gestures = pd.DataFrame()
labels = pd.Series()
labels_array=[]
sizes = [1];
i=0
for root, dirs, files in os.walk("MicrosoftGestureDataset-RC/data"):
    for file in files:
        if file.endswith(".csv"):
            temp = pd.read_csv(os.path.join(root,file),sep=' ',header=None)
#             print int(file[file.find('_',3)+1:file.rfind('_')].replace('A',''))
            numbers[int(file[file.find('_',3)+1:file.rfind('_')].replace('A',''))].append(len(temp))
#             print file
#             gestures[i] = temp.values.flatten()
#             labels_array.append(file[file.find('_',3)+1:file.rfind('_')].replace('A',''))
#             sizes.append(len(temp))
            i=i+1;
print str(i)+" gesture files loaded"

# gestures
# Out:
# 594 gesture files loaded

# %%
df=pd.DataFrame(numbers)
df.T.describe().T
# Out:
#     count         mean          std    min      25%     50%      75%     max
# 0   100.0  1448.340000   755.300425  652.0  1018.00  1193.0  1583.00  5237.0
# 1   104.0  1287.134615   497.682592  539.0   991.50  1139.0  1402.00  3093.0
# 2   100.0  1091.500000   241.357127  639.0   890.00  1063.0  1290.00  1721.0
# 3   104.0  1105.711538   277.687911  735.0   922.25  1017.5  1322.25  2083.0
# 4    97.0  1257.041237  1242.294734    1.0   822.00   980.0  1273.00  9340.0
# 5   106.0  1161.698113   322.259203  670.0   909.00  1121.0  1417.00  1895.0
# 6   108.0  1195.296296   233.143542  804.0  1021.00  1117.5  1338.00  1716.0
# 7   100.0  1095.220000   322.930226  715.0   851.00  1045.5  1211.00  2454.0
# 8   100.0  1368.740000   330.054346  933.0  1117.00  1272.5  1519.00  2308.0
# 9    96.0  1209.958333   434.993234  822.0   940.25  1097.0  1360.50  3538.0
# 10   98.0  1601.979592   753.535871  768.0  1163.00  1524.0  1847.00  5775.0
# 11  100.0  1077.460000   218.974120  606.0   923.00  1046.0  1184.00  1554.0
