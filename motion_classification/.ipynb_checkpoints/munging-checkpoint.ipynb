# %%
import scipy.io as sio;
import matplotlib as plt;
# %matplotlib inline
import pandas as pd;
# raw = pd.read_csv('Joegestures/kinectlog_2016_6_2_529747417_1.txt',sep=' ',index_col=None,lineterminator='\r\n')
# raw2 = pd.read_csv('Joegestures/kinectlog_2016_6_2_529851043_2.txt',sep=' ')
raw4 = pd.read_csv('gestures/Joegestures/kinectlog_2016_6_2_529747417_1.csv', sep=' ')
# raw3 = pd.read_csv('Joegestures/kinectlog_2016_6_2_529747417_1.txt',sep=' ',lineterminator='\r\n')

# raw3 = pd.read_csv('Joegestures/kinectlog_2016_6_2_529747417_1.txt',sep=' ',lineterminator='\r\n')
# it appears not all the columns are labelled, throwing off the DataFrame indexing

# %%
raw4.T
# Out:
#              0           1           2           3           4           5    \
# Time   28.000000   64.000000   96.000000  129.000000  164.000000  196.000000
# LHx   -33.115596  -33.100620  -33.087033  -33.073199  -33.058882  -33.045757
# LHy   -27.856287  -27.866939  -27.877730  -27.891591  -27.906877  -27.921027
# LHz   224.154615  224.143004  224.130416  224.115944  224.099231  224.083996
# LSx   -34.548232  -34.542894  -34.537596  -34.531474  -34.525472  -34.519219
# LSy    29.393327   29.395524   29.397684   29.399645   29.400998   29.401737
# LSz   240.122938  240.135336  240.147567  240.159607  240.171528  240.182424
# RHx     4.803244    4.805459    4.807806    4.810277    4.813689    4.817143
# RHy   -27.580220  -27.587980  -27.595070  -27.602866  -27.611381  -27.619588
# RHz   223.603487  223.607707  223.611331  223.615241  223.619938  223.624659
# RSx     0.570800    0.579429    0.588908    0.599676    0.610890    0.621892
# ...

# %%
file.read(open('Joegestures/kinectlog_2016_6_2_529747417_1.txt'))

# %%
the_plot = plt.pyplot.figure()
# the_plot.
the_plot.axes

# %%
p = raw.CSx.plot()

# %%
raw.CSz.plot()

# %%
raw.T.plot()
legend().set_visible(False)

# %%
raw3 = pd.read_csv('gestures/Gestures6_20_16andafterfolder/Matt_622/10a.txt',sep=" ")
# time term, motion unit & weight term
# raw3['skp_LH.weighttrm']
raw3['skp_LH.timetrm']
# raw3
# Out:
# 25       4.0
# 56       4.0
# 95       4.0
# 125      4.0
# 157      4.0
# 192      4.0
# 231      4.0
# 260      4.0
# 293      4.0
# 325      4.0
# 358      4.0
# 393      4.0
# 425      4.0
# 457      4.0
# 488      4.0
# 522      4.0
# 559      4.0
# 589      4.0
# 626      4.0
# 657      4.0
# 690      4.0
# 727      4.0
# 757      4.0
# 793      4.0
# 825      4.0
# 861      4.0
# 893      4.0
# 925      4.0
# 960      4.0
# 993      4.0
#         ...
# 16131    5.0
# 16163    5.0
# 16198    5.0
# 16229    5.0
# 16265    5.0
# 16299    5.0
# 16328    5.0
# 16365    5.0
# 16396    5.0
# 16436    5.0
# 16466    5.0
# 16502    5.0
# 16533    5.0
# 16568    5.0
# 16598    5.0
# 16629    5.0
# 16661    5.0
# 16695    5.0
# 16728    5.0
# 16762    5.0
# 16794    5.0
# 16829    5.0
# 16861    5.0
# 16897    5.0
# 16930    5.0
# 16961    5.0
# 16997    5.0
# 17028    5.0
# 17065    5.0
# 17097    5.0
# Name: skp_LH.timetrm, dtype: float64
