# %%
import scipy.io as sio;
import matplotlib as plt;
# %matplotlib inline
import pandas as pd;
from sklearn.naive_bayes import GaussianNB;
import os;
gestures = pd.DataFrame()

# %%
sample = pd.read_csv('gestures/Conorgestures/kinectlog_2016_6_2_515849232_1.csv',sep=' ');
(sample.LHx.mean())
# Out:
# -31.267618071111134

# %%
sample.LHx.describe()
# Out:
# count    450.000000
# mean     -31.267618
# std       13.273771
# min      -64.480650
# 25%      -42.385252
# 50%      -21.178528
# 75%      -20.541601
# max      -19.681968
# Name: LHx, dtype: float64

# %%
sample = pd.read_csv('gestures/Joegestures/kinectlog_2016_6_2_529747417_1.csv',sep=' ');
(sample.LHx.mean())
# Out:
# -43.35302784615386

# %%
sample2 = pd.read_csv('gestures/Conorgestures/kinectlog_2016_6_2_515919828_2.csv',sep=' ');
sample2.LHx.mean()
# Out:
# -18.09031931150794

# %%
sample3 = pd.read_csv('gestures/Conorgestures/kinectlog_2016_6_2_515969221_3.csv',sep=' ');
sample3.LHx.mean()
# Out:
# -12.904063153645849

# %%
column_names = sample3.columns
sample3.mean()
if 'NaN' not in sample.mean():
    print True
# Out:
# True

# %%
labels = []

# %%
# Batch import all gesture files
# Taking mean of each feature to 'flatten' data
import os
i=0;
for root, dirs, files in os.walk("gestures"):
    for file in files:
        if file.endswith(".csv"):
            temp = pd.read_csv(os.path.join(root,file),sep=' ')
            gestures[i] = temp.mean()
            if 'NaN' not in temp.mean():
                labels.extend(file[file.rfind('_')+1:-4])
            i=i+1;
# TO DO - organize into (flat) datasets and labels

# %%
# drop features that didn't import properly
# gestures_clean = gestures.dropna?
gestures
# Out:
#                                        0            1            2   \
# Time                          6449.181347  5889.416431  6267.170213
# LHx                             -5.148715    -3.686481   -20.348233
# LHy                            -12.293111   -20.264554   -37.707067
# LHz                            191.739676   189.018099   228.995413
# LSx                             -6.007032    -6.822096   -16.919815
# LSy                             19.945802    20.407315    18.763332
# LSz                            213.950603   209.923425   237.913392
# RHx                             25.789848    20.554738    20.266683
# RHy                            -11.699819   -20.085783   -37.655836
# RHz                            190.728742   187.162507   229.396782
# RSx                             27.765832    25.991687    16.154128
# RSy                             21.113987    20.961987    19.106166
# RSz                            212.547058   206.117538   237.597765
# ...

# %%
gestures_clean = gestures.dropna(axis=0,how='any')
gestures_clean.drop('Time')
# Out:
#              0           1           2           3           4           5   \
# LHx   -5.148715   -3.686481  -20.348233   -5.962493  -10.066738   -8.270152
# LHy  -12.293111  -20.264554  -37.707067   -8.550937  -25.646741  -11.467447
# LHz  191.739676  189.018099  228.995413  189.781308  201.588561  190.562439
# LSx   -6.007032   -6.822096  -16.919815   -4.043570  -15.193950   -8.115434
# LSy   19.945802   20.407315   18.763332   20.378360   18.889828   19.780788
# LSz  213.950603  209.923425  237.913392  203.972172  217.143513  202.240168
# RHx   25.789848   20.554738   20.266683   23.480077   17.184124   23.451047
# RHy  -11.699819  -20.085783  -37.655836   -9.909088  -25.923771   -8.910445
# RHz  190.728742  187.162507  229.396782  187.486618  201.579551  188.941708
# RSx   27.765832   25.991687   16.154128   27.233836   18.219691   24.146114
# RSy   21.113987   20.961987   19.106166   21.030586   20.204694   20.323470
# ...

# %%
labels
# Out:
# ['1',
#  '2',
#  '1',
#  '0',
#  '2',
#  '1',
#  '3',
#  '3',
#  '9',
#  '1',
#  '1',
#  '1',
#  '8',
#  '6',
#  '4',
#  '5',
#  '3',
#  '5',
#  '1',
#  '1',
#  '1',
#  '6',
#  '8',
#  '1',
#  '2',
#  '4',
#  '9',
#  '2',
#  '1',
#  '3',
#  '8',
#  '2',
#  '5',
#  '6',
#  '3',
#  '4',
#  '1',
#  '0',
#  '1',
#  '1',
#  '1',
#  '9',
#  '1',
#  '2',
#  '4',
#  '5',
#  '9',
#  '1',
#  '3',
#  '1',
#  '0',
#  '3',
#  '8',
#  '1',
#  '2',
#  '6',
#  '1',
#  '2',
#  '1',
#  '0',
#  '2',
#  '1',
#  '3',
#  '3',
#  '9',
#  '1',
#  '1',
#  '1',
#  '8',
#  '6',
#  '4',
#  '5',
#  '3',
#  '5',
#  '1',
#  '1',
#  '1',
#  '6',
#  '8',
#  '1',
#  '2',
#  '4',
#  '9',
#  '2',
#  '1',
#  '3',
#  '8',
#  '2',
#  '5',
#  '6',
#  '3',
#  '4',
#  '1',
#  '0',
#  '1',
#  '1',
#  '1',
#  '9',
#  '1',
#  '2',
#  '4',
#  '5',
#  '9',
#  '1',
#  '3',
#  '1',
#  '0',
#  '3',
#  '8',
#  '1',
#  '2',
#  '6',
#  '1',
#  '2',
#  '1',
#  '0',
#  '2',
#  '1',
#  '3',
#  '3',
#  '9',
#  '1',
#  '1',
#  '1',
#  '8',
# ...

# %%
len(labels)
# Out:
# 168

# %%
gnb = GaussianNB()

# %%
y_pred = gnb.fit(gestures_clean.T,labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-652cdfa2aa6a> in <module>()
# ----> 1 y_pred = gnb.fit()
#
# TypeError: fit() takes at least 3 arguments (1 given)
